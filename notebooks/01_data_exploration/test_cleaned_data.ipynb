# %%
import pandas as pd

# %%
df = pd.read_csv('../cleaned_modeling_dataset.csv')

# %%
df.columns.tolist()
# Out:
# ['customer_ref',
#  'application_id',
#  'application_hour',
#  'application_day_of_week',
#  'account_open_year',
#  'preferred_contact',
#  'referral_code',
#  'account_status_code',
#  'num_login_sessions',
#  'num_customer_service_calls',
#  'has_mobile_app',
#  'paperless_billing',
#  'default',
#  'has_referral',
#  'is_business_hours',
#  'is_weekend',
#  'is_evening',
#  'is_morning',
#  'account_age_years',
#  'is_new_account',
#  'is_old_account',
#  'login_to_service_ratio',
#  'total_engagement',
#  'credit_score',
#  'num_credit_accounts',
#  'oldest_credit_line_age',
#  'oldest_account_age_months',
#  'total_credit_limit',
#  'num_delinquencies_2yrs',
#  'num_inquiries_6mo',
#  'recent_inquiry_count',
#  'num_public_records',
#  'num_collections',
#  'account_diversity_index',
#  'credit_score_category',
#  'is_excellent_credit',
#  'is_poor_credit',
#  'avg_credit_limit_per_account',
#  'credit_history_consistency',
#  'has_delinquencies',
#  'has_public_records',
# ...
